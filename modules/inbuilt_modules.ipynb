# %%
from math import *
print(sqrt(25))
# Out:
# 5.0

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import pi
print(pi)
# Out:
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
# Out:
# 10
